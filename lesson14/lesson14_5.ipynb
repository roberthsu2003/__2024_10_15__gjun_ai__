# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50, 5))
df1 = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index = range(1,51))
df1
# Out:
#      國文  英文   數學   地理  歷史
# 1    88  84   78   65  74
# 2    87  83   73   98  86
# 3    70  89   93   65  54
# 4    58  52   97   71  53
# 5    81  73   95   90  81
# 6    99  91   51   81  52
# 7    89  74   66   64  58
# 8    81  65   78   90  56
# 9    85  74   86   66  74
# 10   75  65   60   53  95
# 11   65  64   91   86  52
# 12   70  60   81   56  59
# 13   99  59   98   75  86
# 14   61  94   53   77  61
# 15   94  53   63   53  54
# 16   76  63   58   94  87
# 17   78  51   98   67  63
# 18   71  71   97   95  84
# 19   77  71   65   87  69
# 20   97  67   80   85  68
# 21   88  62   90   71  71
# 22   63  76   70   68  61
# 23   97  90   71   52  59
# 24   56  56   60  100  74
# 25   97  92   51   64  78
# 26   70  76   75   55  65
# 27   89  56   85   51  79
# 28   56  80   95   52  74
# 29   52  82   86   82  69
# 30   87  96   50   79  69
# 31   76  89   67   65  53
# 32   75  84   75   65  80
# 33   71  65   85   68  84
# 34   62  77   57   75  83
# ...

# %%
df1.index.name = '學號'
df1.columns.name = "科目"

# %%
df1.loc[1].sum()
# Out:
# np.int64(389)

# %%
sum = df1.sum(axis=1)

average = sum / 5

# %%
df1['總分'] = sum
df1['平均'] = average
df1
# Out:
# 科目   國文  英文   數學   地理  歷史   總分    平均
# 學號
# 1    88  84   78   65  74  389  77.8
# 2    87  83   73   98  86  427  85.4
# 3    70  89   93   65  54  371  74.2
# 4    58  52   97   71  53  331  66.2
# 5    81  73   95   90  81  420  84.0
# 6    99  91   51   81  52  374  74.8
# 7    89  74   66   64  58  351  70.2
# 8    81  65   78   90  56  370  74.0
# 9    85  74   86   66  74  385  77.0
# 10   75  65   60   53  95  348  69.6
# 11   65  64   91   86  52  358  71.6
# 12   70  60   81   56  59  326  65.2
# 13   99  59   98   75  86  417  83.4
# 14   61  94   53   77  61  346  69.2
# 15   94  53   63   53  54  317  63.4
# 16   76  63   58   94  87  378  75.6
# 17   78  51   98   67  63  357  71.4
# 18   71  71   97   95  84  418  83.6
# 19   77  71   65   87  69  369  73.8
# 20   97  67   80   85  68  397  79.4
# 21   88  62   90   71  71  382  76.4
# 22   63  76   70   68  61  338  67.6
# 23   97  90   71   52  59  369  73.8
# 24   56  56   60  100  74  346  69.2
# ...
