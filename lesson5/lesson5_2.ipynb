# %% [markdown]
# ## loop

# %%
i = 0
i += 1 
i += 2 
i += 3 
i += 4 
i += 5 
i += 6 
i += 7 
i += 8 
i += 9
i += 10
print(i)
# Out:
# 55

# %%
range(10)
range(1,10)
range(1,10,2)
# Out:
# range(1, 10, 2)

# %%
sum = 0
for i in range(1,11):
    sum += i
sum
# Out:
# 55

# %%
sum = 0
for i in range(1,101):
    sum += i
sum
# Out:
# 5050

# %%
for word in 'python':
    print(word)
# Out:
# p
# y
# t
# h
# o
# n
