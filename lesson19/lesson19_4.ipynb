# %%
import pandas as pd

df1 = pd.read_csv('tips.csv')
df1.columns = ['總票價', '小費', '吸煙者', '日期', '時間', '大小']
df1['小費比例'] = df1['小費'] / df1['總票價']

# %%
def top(df, n=5,column='小費比例'):
    return df.sort_values(by=column,ascending=False).iloc[:n]

top(df1)
# Out:
#        總票價    小費  吸煙者   日期      時間  大小      小費比例
# 172   7.25  5.15  Yes  Sun  Dinner   2  0.710345
# 178   9.60  4.00  Yes  Sun  Dinner   2  0.416667
# 67    3.07  1.00  Yes  Sat  Dinner   1  0.325733
# 232  11.61  3.39   No  Sat  Dinner   2  0.291990
# 183  23.17  6.50  Yes  Sun  Dinner   4  0.280535

# %%
list(df1.groupby('吸煙者'))

# %%
df1.groupby('吸煙者').apply(top)
# Out:
# /tmp/ipykernel_57311/2704321095.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1.groupby('吸煙者').apply(top)
#            總票價    小費  吸煙者    日期      時間  大小      小費比例
# 吸煙者
# No  232  11.61  3.39   No   Sat  Dinner   2  0.291990
#     149   7.51  2.00   No  Thur   Lunch   2  0.266312
#     51   10.29  2.60   No   Sun  Dinner   2  0.252672
#     185  20.69  5.00   No   Sun  Dinner   5  0.241663
#     88   24.71  5.85   No  Thur   Lunch   2  0.236746
# Yes 172   7.25  5.15  Yes   Sun  Dinner   2  0.710345
#     178   9.60  4.00  Yes   Sun  Dinner   2  0.416667
#     67    3.07  1.00  Yes   Sat  Dinner   1  0.325733
#     183  23.17  6.50  Yes   Sun  Dinner   4  0.280535
#     109  14.31  4.00  Yes   Sat  Dinner   2  0.279525

# %%
import numpy as np
frame = pd.DataFrame({'data1':np.random.randn(1000),
                      'data2':np.random.randn(1000)})
frame
# Out:
#         data1     data2
# 0   -1.358090  0.223535
# 1   -1.386065 -1.566068
# 2   -0.362001 -0.263908
# 3   -0.766753 -1.209417
# 4   -0.270998  0.147699
# ..        ...       ...
# 995  0.060103 -0.798615
# 996  1.064285  0.380180
# 997  0.053847  0.453531
# 998 -1.192808  0.978113
# 999  0.167978 -0.319999
#
# [1000 rows x 2 columns]

# %%
quartiles = pd.cut(frame.data1,4)

# %%
list(frame.data2.groupby(quartiles))
# Out:
# /tmp/ipykernel_57311/2900926345.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   list(frame.data2.groupby(quartiles))
# [(Interval(-3.133, -1.528, closed='right'),
#   21     0.355617
#   35     0.110236
#   47    -0.571248
#   64     0.933961
#   118   -0.295575
#   119   -0.702288
#   121    0.376824
#   122   -0.576721
#   144    1.170672
#   163   -0.105784
#   202   -0.730140
#   208    0.910705
#   260   -1.292992
#   284   -0.805575
#   308   -2.220995
#   322   -0.576757
#   335   -0.397580
#   347    0.438521
#   365    2.048227
#   371   -0.332623
#   387   -0.045622
#   395   -0.162874
#   422    0.134404
#   437   -0.760911
#   441   -0.833374
#   443    1.620899
#   481   -0.095765
#   510   -0.314054
#   530    1.689804
#   533   -0.315192
#   563   -0.492311
#   569    1.619894
#   572    0.032635
#   577    0.768302
#   580   -0.873891
#   614   -0.104570
#   618   -1.553658
#   654    0.171916
#   681   -0.078135
#   707   -1.303684
#   756    1.467806
#   759   -1.904791
#   780   -1.588258
#   800    1.429725
#   841   -0.728692
#   878    1.113508
#   895    0.658022
#   897    1.442992
#   898    0.429657
#   917   -0.931853
#   923    0.810471
#   954   -1.361757
#   966   -2.357337
#   981   -0.602706
#   Name: data2, dtype: float64),
#  (Interval(-1.528, 0.0713, closed='right'),
#   0      0.223535
#   1     -1.566068
#   2     -0.263908
#   3     -1.209417
#   4      0.147699
#            ...
#   993    0.593825
#   994    0.301558
#   995   -0.798615
#   997    0.453531
#   998    0.978113
#   Name: data2, Length: 423, dtype: float64),
#  (Interval(0.0713, 1.67, closed='right'),
#   5     -1.569334
#   6      1.431341
#   7      0.169748
#   10     0.170591
#   15     1.320169
#            ...
#   989   -1.102526
#   990   -2.065575
#   991    1.896060
#   996    0.380180
#   999   -0.319999
#   Name: data2, Length: 475, dtype: float64),
#  (Interval(1.67, 3.27, closed='right'),
#   38    -0.335818
#   45    -0.016402
#   61     0.421401
#   67    -1.111316
#   111   -0.442185
#   113    0.997828
#   156    1.307846
#   164    0.987239
#   198    0.030017
#   205    2.110672
#   218   -0.759422
#   280    0.095854
#   292    0.726155
#   295   -0.292767
#   325   -0.287395
#   330    0.085998
#   332    2.470616
#   368    0.306885
#   398    1.738699
#   410    0.640208
#   434   -1.564433
#   445   -1.479570
#   455    1.252654
#   463   -1.279945
#   509    2.041893
#   535   -0.752539
#   558    0.874809
#   564   -0.321808
#   566    0.859783
#   583    1.651396
#   585    0.725294
#   598   -2.050547
#   625    1.077410
#   652    0.260909
#   659   -0.097961
#   692    0.253496
#   711   -0.191961
#   771    0.609886
#   806    1.350691
#   826    1.536129
#   855    0.234804
#   861   -0.428070
#   892    2.659870
#   902   -0.289174
#   909    0.747102
#   933   -1.684770
#   987    0.074121
#   992   -0.421307
#   Name: data2, dtype: float64)]
